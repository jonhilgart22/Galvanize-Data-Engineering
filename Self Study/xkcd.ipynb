# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xkcd()
plt.plot(linspace(0, 9, 10))
plt.title('My Computer Science Journey')
xlabel('Knowledge of Computer Science')
ylabel('How Funny  I think XKCD is');
